# %% [markdown]
# <a href="https://colab.research.google.com/github/SainRigo/Resnet_plum_prun20/blob/main/Untitled35_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import os


# we access the file where are store our images

print(os.listdir("/content/drive/MyDrive/plum_data/plum_data/"))
# Out:
# ['Good', 'Bad']

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, AveragePooling2D
from tensorflow.keras.layers import Concatenate , Flatten , Dense , Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet121 , VGG16
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import normalize
from tensorflow.keras.optimizers import Adam

# %%
defective_path_l = os.listdir('/content/drive/MyDrive/plum_data/plum_data/Bad/')
good_path_l = os.listdir('/content/drive/MyDrive/plum_data/plum_data/Good/')
len(defective_path_l)+ len(good_path_l)
# Out:
# 4507

# %%
Image_data = []        # in this list will be append all the images read
Labels_image = []      # in this list will be append the label (statu) in the same oder of each image


# here is the path to the infected images.
# we used a for loop with a step 2 to just read half of the images.

defective_path = "/content/drive/MyDrive/plum_data/plum_data/Bad/"
defective_path_l.sort()

for i in range(0, len(defective_path_l), 2):
    image_path = os.path.join(defective_path, defective_path_l[i])
    images_pil = cv2.imread(image_path)
    image_array = Image.fromarray(images_pil , 'RGB')                     # read of image as RGB
    resize_img = image_array.resize((224 , 224))                          # resizing of image
    Image_data.append(np.array(resize_img))
    Labels_image.append(1)                                                # label on the image


# here we look for the total number of images read and the number of labels in our list
len(Image_data), len(Labels_image)
# Out:
# (1877, 1877)

# %%
good_path = "/content/drive/MyDrive/plum_data/plum_data/Good/"
good_path_l.sort()

for j in range(0, len(good_path_l), 2):
    image_pathu = os.path.join(good_path, good_path_l[j])
    images_pilu = cv2.imread(image_pathu)
    image_arrayu = Image.fromarray(images_pilu, 'RGB')
    resize_imgu = image_arrayu.resize((224 , 224))
    Image_data.append(np.array(resize_imgu))
    Labels_image.append(0)

# we labeled the uninfected cells as 0


# here is the total images for the study
len(Image_data), len(Labels_image)
# Out:
# (2254, 2254)

# %%
cells = np.array(Image_data)
labels = np.array(Labels_image)

# %%
print('Shape of Cells : {} , shape of labels : {}'.format(cells.shape , labels.shape))
# Out:
# Shape of Cells : (2254, 224, 224, 3) , shape of labels : (2254,)

# %%
plt.figure(1 , figsize = (15 , 9))
n = 0
for i in range(8):
    n += 1
    r = np.random.randint(0 , cells.shape[0] , 1)
    plt.subplot(4 , 4 , n)
    plt.subplots_adjust(hspace = 0.56, wspace = 0.56)
    plt.imshow(cells[r[0]])
    plt.title('{} : {}'.format('defective fruit image' if labels[r[0]] == 1 else 'good fruit image' ,
                               labels[r[0]]) )
    plt.xticks([]) , plt.yticks([])

plt.show()

# %%
n = np.arange(cells.shape[0])
np.random.shuffle(n)
cells = cells[n]
labels = labels[n]

# %%
cells = cells.astype(np.float32)/255.00
labels = labels.astype(np.int32)

# %%
# we split the data into train, test and validation set

from sklearn.model_selection import train_test_split

train_x , X , train_y , Y = train_test_split(cells , labels, test_size = 0.3 , random_state = 111)

test_x, valid_x, test_y, valid_y = train_test_split(X,Y, test_size = 0.5, random_state= 111)

# %%
print('Proportion of the data:')
print("train set: X_train: {}, Y_train: {}".format(train_x.shape, train_y.shape))
print('%===============================================%')
print('Validation set: x_validation: {}, y_validation: {}'.format(valid_x.shape, valid_y.shape))
print('%===============================================%')
print("test shape: x_test: {}, y_test: {}".format(test_x.shape, test_y.shape))
# Out:
# Proportion of the data:
# train set: X_train: (1577, 224, 224, 3), Y_train: (1577,)
# %===============================================%
# Validation set: x_validation: (339, 224, 224, 3), y_validation: (339,)
# %===============================================%
# test shape: x_test: (338, 224, 224, 3), y_test: (338,)

# %%
plt.figure(1 , figsize = (15 ,5))
n = 0
for z , j in zip([train_y , valid_y,  test_y] , ['train labels','validation labels', 'test labels']):
    n += 1
    plt.subplot(1 , 3  , n)
    sns.countplot(x = z )
    plt.title(j)
plt.show()

# %%
# !pip install tensorflow_model_optimization
# Out:
# Collecting tensorflow_model_optimization
#   Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow_model_optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_model_optimization) (0.1.8)
# Requirement already satisfied: numpy~=1.23 in /usr/local/lib/python3.10/dist-packages (from tensorflow_model_optimization) (1.25.2)
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow_model_optimization) (1.16.0)
# Installing collected packages: tensorflow_model_optimization
# Successfully installed tensorflow_model_optimization-0.8.0

# %%
import tensorflow_model_optimization

# %%
from tensorflow.keras.losses import BinaryCrossentropy

# %%
import tensorflow_model_optimization
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow_model_optimization.sparsity import keras as sparsity

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *


def resnet(input_shape, n_classes):

  def conv_bn_rl(x, f, k=1, s=1, p='same'):
    x = Conv2D(f, k, strides=s, padding=p)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x


  def identity_block(tensor, f):
    x = conv_bn_rl(tensor, f)
    x = conv_bn_rl(x, f, 3)
    x = Conv2D(4*f, 1)(x)
    x = BatchNormalization()(x)

    x = Add()([x, tensor])
    output = ReLU()(x)
    return output


  def conv_block(tensor, f, s):
    x = conv_bn_rl(tensor, f)
    x = conv_bn_rl(x, f, 3, s)
    x = Conv2D(4*f, 1)(x)
    x = BatchNormalization()(x)

    shortcut = Conv2D(4*f, 1, strides=s)(tensor)
    shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    output = ReLU()(x)
    return output


  def resnet_block(x, f, r, s=2):
    x = conv_block(x, f, s)
    for _ in range(r-1):
      x = identity_block(x, f)
    return x


  input = Input(input_shape)

  x = conv_bn_rl(input, 64, 7, 2)
  x = MaxPool2D(3, strides=2, padding='same')(x)

  x = resnet_block(x, 64, 3, 1)
  x = resnet_block(x, 128, 4)
  x = resnet_block(x, 256, 6)
  x = resnet_block(x, 512, 3)

  x = GlobalAvgPool2D()(x)

  output = Dense(n_classes, activation='softmax')(x)

  model = Model(input, output)
  return model

n_classes = 2  # Replace with the actual number of classes in your classification problem

# Create the model instance using the resnet function
input_shape=(224, 224, 3)
model = resnet(input_shape, n_classes)

# Compile the model
model.compile(loss=BinaryCrossentropy(),
              optimizer=Adam(learning_rate=0.01),
              metrics=['accuracy'])

# Define the pruning parameters
pruning_params = {
    'pruning_schedule': sparsity.ConstantSparsity(target_sparsity=0.20, begin_step=0, end_step=-1, frequency=100)
}

# Apply pruning to the model
pruned_model = tf.keras.models.clone_model(model)
pruned_model = sparsity.prune_low_magnitude(pruned_model, **pruning_params)
pruned_model.build(input_shape)  # Rebuild the model after pruning

# Compile the pruned model
pruned_model.compile(loss=BinaryCrossentropy(),
                     optimizer=Adam(learning_rate=0.01),
                     metrics=['accuracy'])

pruned_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  prune_low_magnitude_conv2d  (None, 112, 112, 64)         18882     ['input_3[0][0]']
#  _106 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_  (None, 112, 112, 64)         257       ['prune_low_magnitude_conv2d_1
#  normalization_106 (PruneLo                                         06[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 112, 112, 64)         1         ['prune_low_magnitude_batch_no
#  98 (PruneLowMagnitude)                                             rmalization_106[0][0]']
#
#  prune_low_magnitude_max_po  (None, 56, 56, 64)           1         ['prune_low_magnitude_re_lu_98
#  oling2d_2 (PruneLowMagnitu                                         [0][0]']
#  de)
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           8258      ['prune_low_magnitude_max_pool
#  _107 (PruneLowMagnitude)                                           ing2d_2[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_1
#  normalization_107 (PruneLo                                         07[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  99 (PruneLowMagnitude)                                             rmalization_107[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           73794     ['prune_low_magnitude_re_lu_99
#  _108 (PruneLowMagnitude)                                           [0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_1
#  normalization_108 (PruneLo                                         08[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  100 (PruneLowMagnitude)                                            rmalization_108[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 256)          33026     ['prune_low_magnitude_re_lu_10
#  _109 (PruneLowMagnitude)                                           0[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 256)          33026     ['prune_low_magnitude_max_pool
#  _110 (PruneLowMagnitude)                                           ing2d_2[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_109 (PruneLo                                         09[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_batch_  (None, 56, 56, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_110 (PruneLo                                         10[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_32  (None, 56, 56, 256)          1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_109[0][0]',
#                                                                      'prune_low_magnitude_batch_no
#                                                                     rmalization_110[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 256)          1         ['prune_low_magnitude_add_32[0
#  101 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           32834     ['prune_low_magnitude_re_lu_10
#  _111 (PruneLowMagnitude)                                           1[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_1
#  normalization_111 (PruneLo                                         11[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  102 (PruneLowMagnitude)                                            rmalization_111[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           73794     ['prune_low_magnitude_re_lu_10
#  _112 (PruneLowMagnitude)                                           2[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_1
#  normalization_112 (PruneLo                                         12[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  103 (PruneLowMagnitude)                                            rmalization_112[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 256)          33026     ['prune_low_magnitude_re_lu_10
#  _113 (PruneLowMagnitude)                                           3[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_113 (PruneLo                                         13[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_33  (None, 56, 56, 256)          1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_113[0][0]',
#                                                                      'prune_low_magnitude_re_lu_10
#                                                                     1[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 256)          1         ['prune_low_magnitude_add_33[0
#  104 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           32834     ['prune_low_magnitude_re_lu_10
#  _114 (PruneLowMagnitude)                                           4[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_1
#  normalization_114 (PruneLo                                         14[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  105 (PruneLowMagnitude)                                            rmalization_114[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 64)           73794     ['prune_low_magnitude_re_lu_10
#  _115 (PruneLowMagnitude)                                           5[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 64)           257       ['prune_low_magnitude_conv2d_1
#  normalization_115 (PruneLo                                         15[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 64)           1         ['prune_low_magnitude_batch_no
#  106 (PruneLowMagnitude)                                            rmalization_115[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 256)          33026     ['prune_low_magnitude_re_lu_10
#  _116 (PruneLowMagnitude)                                           6[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_116 (PruneLo                                         16[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_34  (None, 56, 56, 256)          1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_116[0][0]',
#                                                                      'prune_low_magnitude_re_lu_10
#                                                                     4[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 256)          1         ['prune_low_magnitude_add_34[0
#  107 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 56, 56, 128)          65666     ['prune_low_magnitude_re_lu_10
#  _117 (PruneLowMagnitude)                                           7[0][0]']
#
#  prune_low_magnitude_batch_  (None, 56, 56, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_117 (PruneLo                                         17[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 56, 56, 128)          1         ['prune_low_magnitude_batch_no
#  108 (PruneLowMagnitude)                                            rmalization_117[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          295042    ['prune_low_magnitude_re_lu_10
#  _118 (PruneLowMagnitude)                                           8[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_118 (PruneLo                                         18[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  109 (PruneLowMagnitude)                                            rmalization_118[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          131586    ['prune_low_magnitude_re_lu_10
#  _119 (PruneLowMagnitude)                                           9[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          262658    ['prune_low_magnitude_re_lu_10
#  _120 (PruneLowMagnitude)                                           7[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_1
#  normalization_119 (PruneLo                                         19[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_1
#  normalization_120 (PruneLo                                         20[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_35  (None, 28, 28, 512)          1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_119[0][0]',
#                                                                      'prune_low_magnitude_batch_no
#                                                                     rmalization_120[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 512)          1         ['prune_low_magnitude_add_35[0
#  110 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          131202    ['prune_low_magnitude_re_lu_11
#  _121 (PruneLowMagnitude)                                           0[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_121 (PruneLo                                         21[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  111 (PruneLowMagnitude)                                            rmalization_121[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          295042    ['prune_low_magnitude_re_lu_11
#  _122 (PruneLowMagnitude)                                           1[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_122 (PruneLo                                         22[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  112 (PruneLowMagnitude)                                            rmalization_122[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          131586    ['prune_low_magnitude_re_lu_11
#  _123 (PruneLowMagnitude)                                           2[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_1
#  normalization_123 (PruneLo                                         23[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_36  (None, 28, 28, 512)          1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_123[0][0]',
#                                                                      'prune_low_magnitude_re_lu_11
#                                                                     0[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 512)          1         ['prune_low_magnitude_add_36[0
#  113 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          131202    ['prune_low_magnitude_re_lu_11
#  _124 (PruneLowMagnitude)                                           3[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_124 (PruneLo                                         24[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  114 (PruneLowMagnitude)                                            rmalization_124[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          295042    ['prune_low_magnitude_re_lu_11
#  _125 (PruneLowMagnitude)                                           4[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_125 (PruneLo                                         25[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  115 (PruneLowMagnitude)                                            rmalization_125[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          131586    ['prune_low_magnitude_re_lu_11
#  _126 (PruneLowMagnitude)                                           5[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_1
#  normalization_126 (PruneLo                                         26[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_37  (None, 28, 28, 512)          1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_126[0][0]',
#                                                                      'prune_low_magnitude_re_lu_11
#                                                                     3[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 512)          1         ['prune_low_magnitude_add_37[0
#  116 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          131202    ['prune_low_magnitude_re_lu_11
#  _127 (PruneLowMagnitude)                                           6[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_127 (PruneLo                                         27[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  117 (PruneLowMagnitude)                                            rmalization_127[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 128)          295042    ['prune_low_magnitude_re_lu_11
#  _128 (PruneLowMagnitude)                                           7[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 128)          513       ['prune_low_magnitude_conv2d_1
#  normalization_128 (PruneLo                                         28[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 128)          1         ['prune_low_magnitude_batch_no
#  118 (PruneLowMagnitude)                                            rmalization_128[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 512)          131586    ['prune_low_magnitude_re_lu_11
#  _129 (PruneLowMagnitude)                                           8[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 512)          2049      ['prune_low_magnitude_conv2d_1
#  normalization_129 (PruneLo                                         29[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_38  (None, 28, 28, 512)          1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_129[0][0]',
#                                                                      'prune_low_magnitude_re_lu_11
#                                                                     6[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 512)          1         ['prune_low_magnitude_add_38[0
#  119 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 256)          262402    ['prune_low_magnitude_re_lu_11
#  _130 (PruneLowMagnitude)                                           9[0][0]']
#
#  prune_low_magnitude_batch_  (None, 28, 28, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_130 (PruneLo                                         30[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 28, 28, 256)          1         ['prune_low_magnitude_batch_no
#  120 (PruneLowMagnitude)                                            rmalization_130[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_12
#  _131 (PruneLowMagnitude)                                           0[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_131 (PruneLo                                         31[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  121 (PruneLowMagnitude)                                            rmalization_131[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_12
#  _132 (PruneLowMagnitude)                                           1[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         1049602   ['prune_low_magnitude_re_lu_11
#  _133 (PruneLowMagnitude)                                           9[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_1
#  normalization_132 (PruneLo                                         32[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_1
#  normalization_133 (PruneLo                                         33[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_39  (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_132[0][0]',
#                                                                      'prune_low_magnitude_batch_no
#                                                                     rmalization_133[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_39[0
#  122 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_12
#  _134 (PruneLowMagnitude)                                           2[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_134 (PruneLo                                         34[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  123 (PruneLowMagnitude)                                            rmalization_134[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_12
#  _135 (PruneLowMagnitude)                                           3[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_135 (PruneLo                                         35[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  124 (PruneLowMagnitude)                                            rmalization_135[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_12
#  _136 (PruneLowMagnitude)                                           4[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_1
#  normalization_136 (PruneLo                                         36[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_40  (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_136[0][0]',
#                                                                      'prune_low_magnitude_re_lu_12
#                                                                     2[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_40[0
#  125 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_12
#  _137 (PruneLowMagnitude)                                           5[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_137 (PruneLo                                         37[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  126 (PruneLowMagnitude)                                            rmalization_137[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_12
#  _138 (PruneLowMagnitude)                                           6[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_138 (PruneLo                                         38[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  127 (PruneLowMagnitude)                                            rmalization_138[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_12
#  _139 (PruneLowMagnitude)                                           7[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_1
#  normalization_139 (PruneLo                                         39[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_41  (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_139[0][0]',
#                                                                      'prune_low_magnitude_re_lu_12
#                                                                     5[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_41[0
#  128 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_12
#  _140 (PruneLowMagnitude)                                           8[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_140 (PruneLo                                         40[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  129 (PruneLowMagnitude)                                            rmalization_140[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_12
#  _141 (PruneLowMagnitude)                                           9[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_141 (PruneLo                                         41[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  130 (PruneLowMagnitude)                                            rmalization_141[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_13
#  _142 (PruneLowMagnitude)                                           0[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_1
#  normalization_142 (PruneLo                                         42[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_42  (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_142[0][0]',
#                                                                      'prune_low_magnitude_re_lu_12
#                                                                     8[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_42[0
#  131 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_13
#  _143 (PruneLowMagnitude)                                           1[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_143 (PruneLo                                         43[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  132 (PruneLowMagnitude)                                            rmalization_143[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_13
#  _144 (PruneLowMagnitude)                                           2[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_144 (PruneLo                                         44[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  133 (PruneLowMagnitude)                                            rmalization_144[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_13
#  _145 (PruneLowMagnitude)                                           3[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_1
#  normalization_145 (PruneLo                                         45[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_43  (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_145[0][0]',
#                                                                      'prune_low_magnitude_re_lu_13
#                                                                     1[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_43[0
#  134 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          524546    ['prune_low_magnitude_re_lu_13
#  _146 (PruneLowMagnitude)                                           4[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_146 (PruneLo                                         46[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  135 (PruneLowMagnitude)                                            rmalization_146[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 256)          1179906   ['prune_low_magnitude_re_lu_13
#  _147 (PruneLowMagnitude)                                           5[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 256)          1025      ['prune_low_magnitude_conv2d_1
#  normalization_147 (PruneLo                                         47[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 256)          1         ['prune_low_magnitude_batch_no
#  136 (PruneLowMagnitude)                                            rmalization_147[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 1024)         525314    ['prune_low_magnitude_re_lu_13
#  _148 (PruneLowMagnitude)                                           6[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 1024)         4097      ['prune_low_magnitude_conv2d_1
#  normalization_148 (PruneLo                                         48[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_44  (None, 14, 14, 1024)         1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_148[0][0]',
#                                                                      'prune_low_magnitude_re_lu_13
#                                                                     4[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 1024)         1         ['prune_low_magnitude_add_44[0
#  137 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 14, 14, 512)          1049090   ['prune_low_magnitude_re_lu_13
#  _149 (PruneLowMagnitude)                                           7[0][0]']
#
#  prune_low_magnitude_batch_  (None, 14, 14, 512)          2049      ['prune_low_magnitude_conv2d_1
#  normalization_149 (PruneLo                                         49[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 14, 14, 512)          1         ['prune_low_magnitude_batch_no
#  138 (PruneLowMagnitude)                                            rmalization_149[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            4719106   ['prune_low_magnitude_re_lu_13
#  _150 (PruneLowMagnitude)                                           8[0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_1
#  normalization_150 (PruneLo                                         50[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  139 (PruneLowMagnitude)                                            rmalization_150[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 2048)           2099202   ['prune_low_magnitude_re_lu_13
#  _151 (PruneLowMagnitude)                                           9[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 2048)           4196354   ['prune_low_magnitude_re_lu_13
#  _152 (PruneLowMagnitude)                                           7[0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 2048)           8193      ['prune_low_magnitude_conv2d_1
#  normalization_151 (PruneLo                                         51[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_batch_  (None, 7, 7, 2048)           8193      ['prune_low_magnitude_conv2d_1
#  normalization_152 (PruneLo                                         52[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_45  (None, 7, 7, 2048)           1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_151[0][0]',
#                                                                      'prune_low_magnitude_batch_no
#                                                                     rmalization_152[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 2048)           1         ['prune_low_magnitude_add_45[0
#  140 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            2097666   ['prune_low_magnitude_re_lu_14
#  _153 (PruneLowMagnitude)                                           0[0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_1
#  normalization_153 (PruneLo                                         53[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  141 (PruneLowMagnitude)                                            rmalization_153[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            4719106   ['prune_low_magnitude_re_lu_14
#  _154 (PruneLowMagnitude)                                           1[0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_1
#  normalization_154 (PruneLo                                         54[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  142 (PruneLowMagnitude)                                            rmalization_154[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 2048)           2099202   ['prune_low_magnitude_re_lu_14
#  _155 (PruneLowMagnitude)                                           2[0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 2048)           8193      ['prune_low_magnitude_conv2d_1
#  normalization_155 (PruneLo                                         55[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_46  (None, 7, 7, 2048)           1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_155[0][0]',
#                                                                      'prune_low_magnitude_re_lu_14
#                                                                     0[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 2048)           1         ['prune_low_magnitude_add_46[0
#  143 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            2097666   ['prune_low_magnitude_re_lu_14
#  _156 (PruneLowMagnitude)                                           3[0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_1
#  normalization_156 (PruneLo                                         56[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  144 (PruneLowMagnitude)                                            rmalization_156[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 512)            4719106   ['prune_low_magnitude_re_lu_14
#  _157 (PruneLowMagnitude)                                           4[0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 512)            2049      ['prune_low_magnitude_conv2d_1
#  normalization_157 (PruneLo                                         57[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 512)            1         ['prune_low_magnitude_batch_no
#  145 (PruneLowMagnitude)                                            rmalization_157[0][0]']
#
#  prune_low_magnitude_conv2d  (None, 7, 7, 2048)           2099202   ['prune_low_magnitude_re_lu_14
#  _158 (PruneLowMagnitude)                                           5[0][0]']
#
#  prune_low_magnitude_batch_  (None, 7, 7, 2048)           8193      ['prune_low_magnitude_conv2d_1
#  normalization_158 (PruneLo                                         58[0][0]']
#  wMagnitude)
#
#  prune_low_magnitude_add_47  (None, 7, 7, 2048)           1         ['prune_low_magnitude_batch_no
#   (PruneLowMagnitude)                                               rmalization_158[0][0]',
#                                                                      'prune_low_magnitude_re_lu_14
#                                                                     3[0][0]']
#
#  prune_low_magnitude_re_lu_  (None, 7, 7, 2048)           1         ['prune_low_magnitude_add_47[0
#  146 (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_global  (None, 2048)                 1         ['prune_low_magnitude_re_lu_14
#  _average_pooling2d_2 (Prun                                         6[0][0]']
#  eLowMagnitude)
#
#  prune_low_magnitude_dense_  (None, 2)                    8196      ['prune_low_magnitude_global_a
#  2 (PruneLowMagnitude)                                              verage_pooling2d_2[0][0]']
#
# ==================================================================================================
# Total params: 47051046 (179.49 MB)
# Trainable params: 23538690 (89.79 MB)
# Non-trainable params: 23512356 (89.69 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

# Learning rate is also a hyperparameter
model.compile(loss=BinaryCrossentropy(),
              optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

import tensorflow as tf

# %%
# Resize the training and validation data
train_x_resized = tf.image.resize(train_x, size=(224, 224))
valid_x_resized = tf.image.resize(valid_x, size=(224, 224))

# %%
import tensorflow as tf

# Convert labels to one-hot encoded format
train_y_one_hot = tf.keras.utils.to_categorical(train_y, num_classes=n_classes)
valid_y_one_hot = tf.keras.utils.to_categorical(valid_y, num_classes=n_classes)

# Compile the model
pruned_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define the UpdatePruningStep callback
callbacks = [
    sparsity.UpdatePruningStep()
]

# Train the model with the one-hot encoded labels and include the UpdatePruningStep callback
history = pruned_model.fit(
    train_x_resized,
    train_y_one_hot,
    epochs=16,
    validation_data=(valid_x_resized, valid_y_one_hot),
    callbacks=callbacks)
# Out:
# Epoch 1/16
# 50/50 [==============================] - 1420s 27s/step - loss: 0.5909 - accuracy: 0.8174 - val_loss: 0.5593 - val_accuracy: 0.7817
# Epoch 2/16
# 50/50 [==============================] - 1317s 26s/step - loss: 0.3472 - accuracy: 0.8472 - val_loss: 0.6009 - val_accuracy: 0.7906
# Epoch 3/16
# 50/50 [==============================] - 1310s 26s/step - loss: 0.3095 - accuracy: 0.8605 - val_loss: 0.5834 - val_accuracy: 0.7935
# Epoch 4/16
# 50/50 [==============================] - 1308s 26s/step - loss: 0.2674 - accuracy: 0.8808 - val_loss: 0.5048 - val_accuracy: 0.7906
# Epoch 5/16
# 50/50 [==============================] - 1297s 26s/step - loss: 0.2751 - accuracy: 0.8738 - val_loss: 0.4565 - val_accuracy: 0.7876
# Epoch 6/16
# 50/50 [==============================] - 1303s 26s/step - loss: 0.2505 - accuracy: 0.8840 - val_loss: 0.9706 - val_accuracy: 0.2655
# Epoch 7/16
# 50/50 [==============================] - 1312s 26s/step - loss: 0.2315 - accuracy: 0.8954 - val_loss: 1.0749 - val_accuracy: 0.3510
# Epoch 8/16
# 50/50 [==============================] - 1304s 26s/step - loss: 0.2418 - accuracy: 0.8954 - val_loss: 0.5234 - val_accuracy: 0.7375
# Epoch 9/16
# 50/50 [==============================] - 1296s 26s/step - loss: 0.2288 - accuracy: 0.8935 - val_loss: 1.7162 - val_accuracy: 0.2743
# Epoch 10/16
# 50/50 [==============================] - 1261s 25s/step - loss: 0.3209 - accuracy: 0.8840 - val_loss: 2.8820 - val_accuracy: 0.3245
# Epoch 11/16
# 50/50 [==============================] - 1269s 25s/step - loss: 0.2997 - accuracy: 0.8668 - val_loss: 6.2388 - val_accuracy: 0.7699
# Epoch 12/16
# 50/50 [==============================] - 1275s 26s/step - loss: 0.2569 - accuracy: 0.8732 - val_loss: 0.8863 - val_accuracy: 0.7316
# Epoch 13/16
# 50/50 [==============================] - 1283s 26s/step - loss: 0.2397 - accuracy: 0.8947 - val_loss: 0.6598 - val_accuracy: 0.6519
# Epoch 14/16
# 50/50 [==============================] - 1311s 26s/step - loss: 0.2115 - accuracy: 0.8979 - val_loss: 0.3710 - val_accuracy: 0.8378
# Epoch 15/16
# 50/50 [==============================] - 1280s 26s/step - loss: 0.1971 - accuracy: 0.9106 - val_loss: 0.2913 - val_accuracy: 0.8614
# Epoch 16/16
# 50/50 [==============================] - 1272s 25s/step - loss: 0.1563 - accuracy: 0.9283 - val_loss: 1.1137 - val_accuracy: 0.7965

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
loss =history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
acc = history.history['accuracy']
val_acc =history.history['val_accuracy']

# %%
plt.plot(epochs, acc, 'g', label = 'Training accuracy')
plt.plot(epochs, val_acc,'r', label = "Validation accuracy")
plt.plot(epochs, loss, 'b', label = 'Training loss')
plt.plot(epochs, val_loss, 'y', label = "Validation loss")
plt.title(" Training and validation metric evolution")
plt.xlabel("Epochs")
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np

# Make predictions on validation data
predictions = pruned_model.predict(valid_x_resized)
predicted_classes = np.argmax(predictions, axis=1)

# Calculate metrics
num_correct = np.sum(predicted_classes == np.argmax(valid_y_one_hot, axis=1))
accuracy = num_correct / valid_y_one_hot.shape[0]

true_positives = np.sum(np.logical_and(predicted_classes == 1, np.argmax(valid_y_one_hot, axis=1) == 1))
false_positives = np.sum(np.logical_and(predicted_classes == 1, np.argmax(valid_y_one_hot, axis=1) != 1))
false_negatives = np.sum(np.logical_and(predicted_classes != 1, np.argmax(valid_y_one_hot, axis=1) == 1))

precision = true_positives / (true_positives + false_positives)
recall = true_positives / (true_positives + false_negatives)
f1 = 2 * (precision * recall) / (precision + recall)

# Print results
print("Accuracy: {:.4f}".format(accuracy))
print("Precision: {:.4f}".format(precision))
print("Recall: {:.4f}".format(recall))
print("F1 Score: {:.4f}".format(f1))
# Out:
# 11/11 [==============================] - 71s 6s/step
# Accuracy: 0.7965
# Precision: 0.7934
# Recall: 1.0000
# F1 Score: 0.8848

# %%
model.save('Resnet.h1')
